# %%
pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 9.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.3 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.6/413.6 kB 11.0 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.33
#     Uninstalling langchain-core-0.3.33:
#       Successfully uninstalled langchain-core-0.3.33
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.5
#     Uninstalling langchain-text-splitters-0.3.5:
#       Successfully uninstalled langchain-text-splitters-0.3.5
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.15
#     Uninstalling langchain-0.3.15:
#       Successfully uninstalled langchain-0.3.15
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.3.15
# ...

# %%
silo1 = SiloTool(name="silo1", description="Silo 1", repository="https://github.com/langchain-ai/langchain")
silo2 = SiloTool(name="silo2", description="Silo 2", repository="https://github.com/langchain-ai/langchain")

tools = [silo2, silo1]

# %%
tools[1].invoke("What is the weather in Tokyo?")
# Out:
# 'My name is silo1'
