# %%
def query_ollama(image_path, prompt):
    base64_image = encode_image_to_base64(image_path)
    
    headers = {
        'Content-Type': 'application/json',
        'Authorization': 'Bearer 3ef62a2bd64cc145f722aa107f58139b9670de495ca08dc983cb6bc0472a2791'
    }
    
    payload = {
        "model": "granite3.2-vision",
        "messages": [
            {
                "role": "user",
                "content": prompt + "\n" + f"{base64_image}"
            }
        ],
        "stream": False
    }
    
    response = requests.post('https://45.135.56.11:27969/api/chat', 
                           json=payload, 
                           verify=False)
    
    # Print status code and raw response
    print(f"Status Code: {response.status_code}")
    print(f"Raw Response: {response.text}")
    
    # Only try to parse JSON if we got a successful response
    if response.status_code == 200:
        return response.json()
    else:
        return f"Error: {response.status_code} - {response.text}"

# Example usage
image_path = "/home/aritz/Descargas/img.png"
prompt = "What do you see in this image?"

# Get response from Ollama
response = query_ollama(image_path, prompt)
print("\nProcessed Response:", response)
# Out:
# Status Code: 401
# Raw Response:
#
# Processed Response: Error: 401 -
# /home/aritz/data/proiektuak/LKS/IA-Core-Tools/ia-core-tools/IA-CORE/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '45.135.56.11'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
